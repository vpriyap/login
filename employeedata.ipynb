# %% [markdown]
# <a href="https://colab.research.google.com/github/vpriyap/login/blob/main/employeedata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Employee": ["Asha","Ravi","Meena","Arjun","Kiran"],
    "Department": ["HR","IT","Finance","IT","HR"],
    "Salary": [40000,55000,50000,60000,42000],
    "Attrition": ["No","Yes","No","No","Yes"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Employee Department  Salary Attrition
# 0     Asha         HR   40000        No
# 1     Ravi         IT   55000       Yes
# 2    Meena    Finance   50000        No
# 3    Arjun         IT   60000        No
# 4    Kiran         HR   42000       Yes
